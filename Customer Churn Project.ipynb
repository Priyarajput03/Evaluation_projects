# %% [markdown]
# ## Importing the libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#setting to display all columns and rows
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
#Loading the dataset
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#Shape of the dataset
df.shape
# Out:
# (7043, 21)

# %%
#Identifying the column name of the dataset
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#Loading Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#Find the null values in the dataset 
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# As we see that their is no value in dataset.so, we are good to go ahead

# %%
#Statistcial Information
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#Indentifying the uniqye values
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
#Finding the unique value count of each columns
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print('------------------------------------------')
# Out:
# customerID
# 4500-HKANN    1
# 7601-GNDYK    1
# 4116-TZAQJ    1
# 7250-EQKIY    1
# 5445-GLVOT    1
# 5339-TJFEK    1
# 5054-IEXZT    1
# 3413-CSSTH    1
# 7021-XSNYE    1
# 3571-DPYUH    1
# 6313-GIDIT    1
# 1750-CSKKM    1
# 5424-RLQLC    1
# 7404-JLKQG    1
# 2834-SPCJV    1
# 9025-ZRPVR    1
# 3530-CRZSB    1
# 8058-INTPH    1
# 3671-SHRSP    1
# 1972-XMUWV    1
# 0397-ZXWQF    1
# 6350-XFYGW    1
# 0464-WJTKO    1
# 4652-NNHNY    1
# 9046-DQMTP    1
# 2439-QKJUL    1
# 6953-PBDIN    1
# 8242-SOQUO    1
# 4282-YMKNA    1
# 6092-QZVPP    1
# 2525-GVKQU    1
# 0485-ZBSLN    1
# 1038-RQOST    1
# 8920-NAVAY    1
# 5360-LJCNJ    1
# 8714-CTZJW    1
# 1936-UAFEH    1
# 2402-TAIRZ    1
# 7876-AEHIG    1
# 0761-AETCS    1
# 0093-EXYQL    1
# 1431-AIDJQ    1
# 9763-GRSKD    1
# 2650-GYRYL    1
# 4720-VSTSI    1
# 3520-FJGCV    1
# 1697-LYYYX    1
# 7206-GZCDC    1
# 5173-WXOQV    1
# 2270-CHBFN    1
# 6474-FVJLC    1
# 6284-AHOOQ    1
# 8931-GJJIQ    1
# 1982-FEBTD    1
# ...

# %%
#dataset data type
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')
# df['TotalCharges']=df['TotalCharges'].astype('float')
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.loc[df['TotalCharges'].isnull()==True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 488            No  No phone service             DSL                  Yes
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df.shape
# Out:
# (7032, 21)

# %%
print(df['tenure'].max())
# Out:
# 72

# %%
#creating tenure in group form
labels=['{0}-{1}'.format(i,i+11) for i in range(1,72,12)]
df['tenure_group']=pd.cut(df.tenure,range(1,80,12),right=False,labels=labels)

# %%
df['tenure_group'].value_counts()
# Out:
# 1-12     2175
# 61-72    1407
# 13-24    1024
# 25-36     832
# 49-60     832
# 37-48     762
# Name: tenure_group, dtype: int64

# %%
df.drop(columns=['customerID','tenure'],axis=1,inplace=True)

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='gender',data=df)
plt.show()

# %%
sns.countplot(x='SeniorCitizen',data=df)
plt.show()

# %%
sns.countplot(x='Dependents',data=df)
plt.show()

# %%
sns.countplot(x='PhoneService',data=df)
plt.show()

# %%
sns.countplot(x='MultipleLines',data=df)
plt.show()

# %%
sns.countplot(x='InternetService',data=df)
plt.show()

# %%
sns.countplot(x='OnlineSecurity',data=df)
plt.show()

# %%
sns.countplot(x='OnlineBackup',data=df)
plt.show()

# %%
sns.countplot(x='DeviceProtection',data=df)
plt.show()

# %%
sns.countplot(x='TechSupport',data=df)
plt.show()

# %%
sns.countplot(x='StreamingTV',data=df)
plt.show()

# %%
sns.countplot(x='StreamingMovies',data=df)
plt.show()

# %%
sns.countplot(x='Contract',data=df)
plt.show()

# %%
sns.countplot(x='PaperlessBilling',data=df)
plt.show()

# %%
sns.countplot(x='PaymentMethod',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Churn',data=df)
plt.show()

# %% [markdown]
# from above plor we observe following things:
#
# 1.gender-male and female count is almost same still male is on slighty higher side
#
# 2.SeniorCitizen:number of senior citizen is less as per graph.count for 0 i.e non-senior citizen is high
#
# 3.Partner: people with no partner are higher than people who have partner.
#
# 4.Dependents: count for depencents is less compared to 0 count
#
# 5.phone Service:people with a phone service cover a large data chunk while there are only few people who do not own a phone service.
#
# 6.Multiple Lines: people with single line are higher in number than people who have multiple lines but we also see a minority of people who do not own a phone service yet.
#
# 7.Internet service:majority of people have chosen to get a high speed fibre optic internet but there are many people who do not own an internet service at all.
#
# 8.Online Security: people who do not have any internet service obviously do not need any online security either but there is a huge number in people who own an internet service but do not use any online security yet.
#
# 9.Online Backup:people with no internet service and online security the same chunk of folks have no online backup usage either. But the difference between people who use internet and do not have online backup vs people who use online back up is relatively lesser as compared to online security details.
#
# 10.Device Protection: people without any device protection is higher in number as compared to people who have some kind of device protection.
#
# 11.Tech Support::people who do not need technical support is higher in number as compared to people who need technical assistance.
#
# 12.Streaming TV: people who do not use streaming TV service is slightly higher than the people who do use streaming TV service.
#
# 13.Streamin Movies:people who do not stream movies a slight higher than people who do enjoy streaming movies online.
#
# 14.Contract: there are a lot of people who prefer the month to month contract over the 1 year or 2 year contract term.
#
# 15.Paperless Billing: people who prefer paper less billing are high in number however we still have a huge number of people who prefer the traditional way of receiving a paper bill.
#
# 16.Payment Method:preferred payment amount by people is the electronic check. While people using the mailed check, automatic bank transfer and automatic credit card debit option fall in a similar range of numbers
#
# 17.Churn: "No Churn" values are way higher than "Yes Churn" data. Since this is our target label it indicates an imbalanced data which will need to be rectified later on.

# %% [markdown]
# ## Bivariate Analysis

# %%
for i,predictor in enumerate(df.drop(columns=['Churn','TotalCharges','MonthlyCharges'])):
    plt.figure(i)
    plt.figure(figsize=(10,6))
    sns.countplot(data=df,x=predictor,hue='Churn')

# %%
df['Churn']=np.where(df.Churn=='Yes',1,0)

# %%
df=pd.get_dummies(df)
df.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# 0            0           0            1              1               0
# 1            1           1            0              1               0
# 2            1           1            0              1               0
# 3            1           1            0              1               0
# 4            0           1            0              1               0
#
#    PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0                1                 0                 0
# ...

# %%
sns.lmplot(data=df,x='MonthlyCharges',y='TotalCharges',fit_reg=False)

# %% [markdown]
# Total Charges increases as montly charges increases

# %%
#correlation matrix
df.corr()
# Out:
#                                          SeniorCitizen  MonthlyCharges  \
# SeniorCitizen                                 1.000000        0.219874
# MonthlyCharges                                0.219874        1.000000
# TotalCharges                                  0.102411        0.651065
# Churn                                         0.150541        0.192858
# gender_Female                                 0.001819        0.013779
# gender_Male                                  -0.001819       -0.013779
# Partner_No                                   -0.016957       -0.097825
# Partner_Yes                                   0.016957        0.097825
# Dependents_No                                 0.210550        0.112343
# Dependents_Yes                               -0.210550       -0.112343
# PhoneService_No                              -0.008392       -0.248033
# PhoneService_Yes                              0.008392        0.248033
# ...

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,linecolor='black',linewidth=0.5,fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Splitting the features and labels into x and Y variables

# %%
x=df.drop('Churn',axis=1)
y=df['Churn']

# %%
y.value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# As we see data is imbalance .so we are balancing it using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# adding samples to make all the categorical label values same

oversample=SMOTE()
x,y = oversample.fit_resample(x,y)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0      -0.397998       -1.331225     -0.923736       1.164440    -0.873682
# 1      -0.397998       -0.384320     -0.067847      -0.858782     1.144582
# 2      -0.397998       -0.492637     -0.887699      -0.858782     1.144582
# 3      -0.397998       -0.896208     -0.090284      -0.858782     1.144582
# 4      -0.397998        0.096121     -0.867679       1.164440    -0.873682
#
#    Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# 0   -1.001939     1.276252       0.647446       -0.524378         3.386889
# 1    0.998065    -0.783544       0.647446       -0.524378        -0.295256
# 2    0.998065    -0.783544       0.647446       -0.524378        -0.295256
# 3    0.998065    -0.783544       0.647446       -0.524378         3.386889
# 4    0.998065    -0.783544       0.647446       -0.524378        -0.295256
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb


from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Model Building

# %%
max_acc=0
max_RS=0
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    r2=accuracy_score(y_test,pred)*100
    
    if r2>max_acc:
        max_acc=r2
        max_RS=i
print('Best R2 score is',max_acc, 'on random state', max_RS)
# Out:
# Best R2 score is 87.60890609874153 on random state 194

# %%
# Classification Model Function

def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=90)
    
    # Training the model
    model.fit(x_train, y_train)
    
    # Predicting Y_test
    pred = model.predict(x_test)
    
    # Classification Report
    class_report = classification_report(y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    # Accuracy Score
    acc_score = (accuracy_score(y_test, pred))*100
    print("Accuracy Score:", acc_score)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, x, y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of accuracy minus cv scores
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)
    
    print(confusion_matrix(y_test,pred))

# %%
model=RandomForestClassifier()
classify(model,x,y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86      1066
#            1       0.86      0.84      0.85      1000
#
#     accuracy                           0.86      2066
#    macro avg       0.86      0.86      0.86      2066
# weighted avg       0.86      0.86      0.86      2066
#
# Accuracy Score: 85.6243949661181
# Cross Validation Score: 83.45105935133337
#
# Accuracy Score - Cross Validation Score is 2.173335614784733
# [[928 138]
#  [159 841]]

# %%
model=DecisionTreeClassifier()
classify(model,x,y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83      1066
#            1       0.81      0.83      0.82      1000
#
#     accuracy                           0.82      2066
#    macro avg       0.82      0.82      0.82      2066
# weighted avg       0.82      0.82      0.82      2066
#
# Accuracy Score: 82.28460793804453
# Cross Validation Score: 79.78067595029874
#
# Accuracy Score - Cross Validation Score is 2.503931987745787
# [[873 193]
#  [173 827]]

# %%
model=SVC()
classify(model,x,y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87      1066
#            1       0.88      0.82      0.85      1000
#
#     accuracy                           0.86      2066
#    macro avg       0.86      0.86      0.86      2066
# weighted avg       0.86      0.86      0.86      2066
#
# Accuracy Score: 86.06001936108422
# Cross Validation Score: 82.41498819817687
#
# Accuracy Score - Cross Validation Score is 3.645031162907344
# [[954 112]
#  [176 824]]

# %%
model=KNeighborsClassifier()
classify(model,x,y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84      1066
#            1       0.81      0.87      0.84      1000
#
#     accuracy                           0.84      2066
#    macro avg       0.84      0.84      0.84      2066
# weighted avg       0.84      0.84      0.84      2066
#
# Accuracy Score: 84.22071636011617
# Cross Validation Score: 82.66614787086672
#
# Accuracy Score - Cross Validation Score is 1.5545684892494478
# [[866 200]
#  [126 874]]

# %%
model=ExtraTreesClassifier()
classify(model,x,y)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      1066
#            1       0.86      0.81      0.84      1000
#
#     accuracy                           0.85      2066
#    macro avg       0.85      0.85      0.85      2066
# weighted avg       0.85      0.85      0.85      2066
#
# Accuracy Score: 84.80154888673765
# Cross Validation Score: 82.48280356000178
#
# Accuracy Score - Cross Validation Score is 2.318745326735865
# [[938 128]
#  [186 814]]

# %%
from xgboost import XGBClassifier
model=XGBClassifier()
classify(model,x,y)
# Out:
# [12:51:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86      1066
#            1       0.86      0.84      0.85      1000
#
#     accuracy                           0.86      2066
#    macro avg       0.86      0.86      0.86      2066
# weighted avg       0.86      0.86      0.86      2066
#
# Accuracy Score: 85.72120038722169
# ...

# %% [markdown]
# ## Hyper Paramete Tuning for the Best Model

# %% [markdown]
# ## 1.SVC

# %%
#Creating parameters list to pass in GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
sv=SVC()
parameters={"kernel":['linear','rbf'],"C":[1,10]}
kf=KFold(n_splits=5)
gs=GridSearchCV(sv,parameters,cv=kf)
gs.fit(x,y)
print(gs.best_params_)
print(gs.best_score_)
# Out:
# {'C': 1, 'kernel': 'linear'}
# 0.8503819946604662

# %%
Final=SVC(C=1,kernel='linear')
Final.fit(x_train,y_train)
pred=Final.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 83.4946757018393

# %% [markdown]
# ## 2. Tuning with Random Forest Classifier

# %%
parameters = {'max_depth': [10, 20, 30, 40, None],
              'max_features': ['auto', 'sqrt','log2'],
              'min_samples_leaf': [1, 2, 4],
              'min_samples_split': [2, 5, 10],
              'n_estimators': [50, 100, 150]}
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=3)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 30, 40, None],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150]})

# %%
GCV.best_params_
# Out:
# {'max_depth': 40,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'n_estimators': 50}

# %%
Finalmodel=RandomForestClassifier(max_features= 'log2', min_samples_leaf= 1, min_samples_split=10,n_estimators=50,max_depth=40)
Finalmodel.fit(x_train,y_train)
pred=Finalmodel.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 84.6079380445305

# %% [markdown]
# #### We sucessfully incorporated our final model Random Forest Classifier with accuracy score of 84.60%

# %%
plt.style.use('seaborn-bright')
disp = metrics.plot_roc_curve(Final,x_test,y_test)
disp = metrics.plot_roc_curve(Finalmodel,x_test,y_test)
disp.figure_.suptitle("ROC Curve")
plt.show()

# %% [markdown]
# #### AUC Value for FinalModel is 93%

# %%
class_names = df.columns
metrics.plot_confusion_matrix(Finalmodel.fit(x_train,y_train),x_test,y_test,cmap='mako')
plt.title('Confusion Matrix for Random Forest Classifier \n')
plt.show()

# %%
import joblib
filename = "FinalModel_RF.pkl"
joblib.dump(Finalmodel, filename)
# Out:
# ['FinalModel_RF.pkl']
