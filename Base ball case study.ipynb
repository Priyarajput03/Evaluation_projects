# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#converting the .csv file to dataset 
df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#statistical dimensions
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Detailed study of all dataset parameter
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#checking the null values of the dataset
df.isna().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#checking the value counts of the tarhet column from dataset
df['W'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %%
#checking skewness in the dataset
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# from above observation we have seen that their is skewness in some feature columns as the range of skewness lies between +/- 0.5

# %% [markdown]
# ### Visualization

# %% [markdown]
# Using the graphs we understand how each and other attributes are related and how are they contributing in predicting target variable

# %%
#checking the distributin plot of the dataset
plt.figure(figsize=(20,15))
plotnumber=1

for i in df:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[i],color='g')
        plt.xlabel(i, fontsize=15)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Box plot

# %%
# from boxplot we understand how data is divide and also find outlier in the dataset
plt.figure(figsize=(20,20))
plotnumber=1

for i in df:
    if plotnumber<=18:
        ax=plt.subplot(5,4,plotnumber)
        sns.boxplot(df[i],color='r')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Observing the boxplot graph, we have seen that their are outlier in 5 features of dataset(R,E,SV,SHO,ERA) and will be removed using zscore method

# %% [markdown]
# #### Multivariant Analysis

# %%
#using pairplot ,we visualize the relationship of attributes
plt.figure(figsize=(3,3))
sns.pairplot(df, height=1.5)
plt.show()

# %% [markdown]
# ### Lineplot

# %%
for i in df:
    sns.lmplot( x=i,y='W',data=df)

# %%
plt.figure(figsize=(15,15))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar', color='g')
plt.xlabel('Features', fontsize=10)
plt.xlabel('Target', fontsize=10)
plt.xticks(rotation=75)
plt.title('Relationship between Features and Target',fontsize=15)
plt.show()

# %%
df.corr() #correlation matrix
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),annot=True,linecolor='black', linewidth=0.5,fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# In heatmap, we pbserve that it contain both posotive and negative correlation. there is also multicollinerailty between ER,RA and ERA.we also need to remove the highly correlated columns.
# we can also drop column H and CG because there are not having much relation with the target.
#
# Negaively correlated columns are: E,aB, 3B and SB.
#
# Highly Negative columns are: RA, ER and ERA.
#
# Positivly correlated columns are:R,H,2B,HR,BB,SO,CG,SHO and SV

# %%
# df = df.drop(["Earned Runs", "Earned Run Average"], axis=1)
df.drop(['ER','ERA', 'CG','H'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'SHO', 'SV',
#        'E'],
#       dtype='object')

# %% [markdown]
# ## Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB   2B  3B   HR   BB    SO   SB   RA  SHO  SV    E
# 0    95  724  5575  300  42  139  383   973  104  641    8  56   88
# 1    83  696  5467  277  44  156  439  1264   70  700   12  45   86
# 2    81  669  5439  303  29  141  533  1157   86  640   10  38   79
# 3    76  622  5533  260  27  136  404  1231   68  701    9  37  101
# 4    74  689  5605  289  49  151  455  1259   83  803   12  35   86
# 6    87  764  5567  272  19  212  554  1227   63  698    4  48   93
# 7    81  713  5485  246  20  217  418  1331   44  693   10  43   77
# 8    80  644  5485  278  32  167  436  1310   87  642   12  60   95
# 9    78  748  5640  294  33  161  478  1148   71  753   10  40   97
# 10   88  751  5511  279  32  172  503  1233  101  733    9  45  119
# 11   86  729  5459  278  26  230  486  1392  121  618   13  39   85
# 12   85  661  5417  243  21  176  435  1150   52  675   12  46   93
# 13   76  656  5544  262  22  198  478  1336   69  726   12  45   94
# ...

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (30, 13)
# (29, 13)

# %%
#checking the data loss
loss=(30-29)/30*100
loss
# Out:
# 3.3333333333333335

# %% [markdown]
# from above we see that their is 3.33% loss of data which is not much.

# %% [markdown]
# ### IQR method

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# W       13.75
# R       67.00
# AB     106.00
# 2B      26.50
# 3B      16.00
# HR      36.75
# BB      73.00
# SO     154.00
# SB      27.50
# RA      96.25
# SHO      4.00
# SV       9.50
# E       10.75
# dtype: float64

# %%
df1=df[~((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).any(axis=1)]
print(df1.shape)
# Out:
# (21, 13)

# %%
loss1=(30-21)/30*100
loss1
# Out:
# 30.0

# %% [markdown]
# using IQR method their is much loss of data which we can not deal with.so we move forward with zscore

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [raw]
# there are still many columns which is showing skewness

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Splitting the data into X and Y form

# %%
x=df_new.drop('W',axis=1)
y=df_new['W']

# %% [markdown]
# ### Scaling the data using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x), columns=x.columns)
x.head(5)
# Out:
#           R        AB        2B        3B        HR        BB        SO  \
# 0  0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1  0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2 -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3 -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4  0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
#
#          SB        RA       SHO        SV         E
# 0  0.905953 -0.664514 -0.813262  1.643157 -0.471091
# 1 -0.585315  0.154638  0.159299  0.211006 -0.614898
# 2  0.116458 -0.678397 -0.326982 -0.700362 -1.118222
# 3 -0.673037  0.168522 -0.570122 -0.830557  0.463653
# 4 -0.015124  1.584683  0.159299 -1.090948 -0.614898

# %% [markdown]
# ### Principal Component Analysis

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=12, svd_solver='full')
x=pd.DataFrame(pca.fit_transform(x),columns=x.columns)
x.head(5)
# Out:
#           R        AB        2B        3B        HR        BB        SO  \
# 0 -1.848158 -1.391918  2.234986 -2.779728 -0.062176 -1.049359  0.382183
# 1 -0.152919  0.100491  0.353879 -0.444281 -0.570551 -0.279360 -1.203958
# 2  0.550366 -0.117515  1.092091 -0.877402 -0.863116  1.236942  1.330649
# 3 -0.947945  1.894751  0.148055  0.229715  0.862822  0.139922 -0.180630
# 4 -2.115153 -0.820270 -0.158243  0.115836 -0.984273  0.866168 -0.983680
#
#          SB        RA       SHO        SV         E
# 0 -0.747614  0.540104  0.102519  0.282565 -0.139078
# 1  0.758553  0.539613 -0.296413 -0.152969 -0.160819
# 2  1.466561  0.637121  0.804073 -0.031693  0.269266
# 3 -0.261756 -0.632240  0.691314 -0.332871  0.301308
# 4  0.978393 -0.796908 -0.316531  0.213320 -0.030600

# %%
from sklearn.preprocessing import PowerTransformer
p=PowerTransformer(method='yeo-johnson')
x=pd.DataFrame(p.fit_transform(x),columns=x.columns)
x.head(5)
# Out:
#           R        AB        2B        3B        HR        BB        SO  \
# 0 -1.071116 -0.951057  1.711388 -2.525831 -0.168733 -1.244281  0.617621
# 1 -0.018341  0.218840  0.262576 -0.418762 -0.632735 -0.236559 -1.904442
# 2  0.374402  0.071027  0.828664 -0.814057 -0.879338  1.326485  1.567756
# 3 -0.497351  1.211041  0.105557  0.203389  0.834552  0.247770 -0.112563
# 4 -1.246195 -0.463657 -0.127239  0.097543 -0.978082  0.983711 -1.473919
#
#          SB        RA       SHO        SV         E
# 0 -1.192324  0.886656  0.345029  0.803811 -0.404993
# 1  1.183024  0.885884 -0.516116 -0.453053 -0.484920
# 2  2.206531  1.038630  1.458553 -0.109340  0.921928
# 3 -0.389288 -1.036054  1.302602 -0.954918  1.013932
# 4  1.505242 -1.318715 -0.565101  0.599963 -0.020664

# %% [markdown]
# ## Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['features']=x.columns
vif['vif_features']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]

vif
# Out:
#    features  vif_features
# 0         R      1.005924
# 1        AB      1.021124
# 2        2B      1.004674
# 3        3B      1.001865
# 4        HR      1.010164
# 5        BB      1.010106
# 6        SO      1.016209
# 7        SB      1.004243
# 8        RA      1.002458
# 9       SHO      1.010497
# 10       SV      1.003893
# 11        E      1.016047

# %% [markdown]
# with values around 1 means we are in good shape, and can proceed with our regression

# %%
x.head()
# Out:
#           R        AB        2B        3B        HR        BB        SO  \
# 0 -1.071116 -0.951057  1.711388 -2.525831 -0.168733 -1.244281  0.617621
# 1 -0.018341  0.218840  0.262576 -0.418762 -0.632735 -0.236559 -1.904442
# 2  0.374402  0.071027  0.828664 -0.814057 -0.879338  1.326485  1.567756
# 3 -0.497351  1.211041  0.105557  0.203389  0.834552  0.247770 -0.112563
# 4 -1.246195 -0.463657 -0.127239  0.097543 -0.978082  0.983711 -1.473919
#
#          SB        RA       SHO        SV         E
# 0 -1.192324  0.886656  0.345029  0.803811 -0.404993
# 1  1.183024  0.885884 -0.516116 -0.453053 -0.484920
# 2  2.206531  1.038630  1.458553 -0.109340  0.921928
# 3 -0.389288 -1.036054  1.302602 -0.954918  1.013932
# 4  1.505242 -1.318715 -0.565101  0.599963 -0.020664

# %% [markdown]
# ## Model Building

# %%
#importing libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
#linear Regression
max_acc=0
max_RS=0
for i in range(0,200):
    x_train,x_test,y_train, y_test= train_test_split(x,y,test_size=0.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>max_acc:
        max_acc=acc
        max_RS=i
print( 'Best r2 score is', max_acc ,'on random state', max_RS)
# Out:
# Best r2 score is 0.9306955014951944 on random state 189

# %% [markdown]
# ## creating training and testing dataset

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=189)

# %% [markdown]
# ### Machine Learning model with regression and evaluation metrics

# %%
def reg(model,x,y):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=189)
    
    model.fit(x_train,y_train) #trainnng the model
    
    pred=model.predict(x_test) 
    
    rmse=mean_squared_error(y_test,pred,squared=False)  # findthe root mean squared error value
    print('RMSE is:',rmse)
    
    r2=r2_score(y_test,pred)*100 # finding r2 score value
    print('r2 score is:',r2)

    cvs=(cross_val_score(model,x,y,cv=5).mean())*100 # cross validation score
    print('Cross validation score is:', cvs)
    
    result=r2-cvs
    print('R2 score -Cross validation score is:', result)

# %%
model=LinearRegression()
reg(model,x,y)
# Out:
# RMSE is: 3.4576040826096555
# r2 score is: 93.06955014951944
# Cross validation score is: -0.025942377266519046
# R2 score -Cross validation score is: 93.09549252678596

# %%
#Lasso Regressor
from sklearn.linear_model import Lasso, Ridge
model=Lasso(alpha=0.01,normalize=True)
reg(model,x,y)
# Out:
# RMSE is: 3.3685246879948703
# r2 score is: 93.42205300079365
# Cross validation score is: 1.3978403138610984
# R2 score -Cross validation score is: 92.02421268693256

# %%
#Ridge Regressor
model=Ridge(alpha=0.01,normalize=True)
reg(model,x,y)
# Out:
# RMSE is: 3.3551396290291287
# r2 score is: 93.47422496795262
# Cross validation score is: 2.2120988113150286
# R2 score -Cross validation score is: 91.26212615663759

# %%
#Suport Vector Regressor
from sklearn.svm import SVR
model=SVR(C=1.0,epsilon= 0.2, kernel= "poly", gamma = "auto")
reg(model,x,y)
# Out:
# RMSE is: 13.083749818377724
# r2 score is: 0.762603298609188
# Cross validation score is: -47.93254063202785
# R2 score -Cross validation score is: 48.69514393063704

# %%
#Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(max_depth=2, max_features='sqrt')
reg(model,x,y)
# Out:
# RMSE is: 11.804031384889292
# r2 score is: 19.225995979448463
# Cross validation score is: -29.471685564959017
# R2 score -Cross validation score is: 48.69768154440748

# %%
#KNeighbors Regressor
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
reg(model,x,y)
# Out:
# RMSE is: 11.452346921046358
# r2 score is: 23.967391304347828
# Cross validation score is: -147.11901497658076
# R2 score -Cross validation score is: 171.0864062809286

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor(criterion='poisson')
reg(model,x,y)
# Out:
# RMSE is: 12.338962679253067
# r2 score is: 11.739130434782608
# Cross validation score is: -102.94367953263288
# R2 score -Cross validation score is: 114.6828099674155

# %%
# Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor
model=GradientBoostingRegressor(loss='quantile',n_estimators=200,max_depth=5)
reg(model,x,y)
# Out:
# RMSE is: 14.753587578543408
# r2 score is: -26.184548659565433
# Cross validation score is: -47.880715566450924
# R2 score -Cross validation score is: 21.69616690688549

# %%
#AdaBoost Regressor
from sklearn.ensemble import AdaBoostRegressor
model=AdaBoostRegressor(n_estimators=200,learning_rate=1.05)
reg(model,x,y)
# Out:
# RMSE is: 10.584282089617966
# r2 score is: 35.05679573761874
# Cross validation score is: -7.709766737624027
# R2 score -Cross validation score is: 42.76656247524277

# %% [markdown]
# ## Hypertunning Parameter for selected model

# %%
from sklearn.model_selection import GridSearchCV
param={'fit_intercept':[True, False],'normalize':[True,False],'copy_X':[True, False]}
grid_cv=GridSearchCV(LinearRegression(),param,cv=5)
grid_cv.fit(x_train,y_train)
grid_cv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
grid_lr=LinearRegression(copy_X=True, fit_intercept= True, normalize= False)
grid_lr.fit(x_train,y_train)
grid_pred=grid_lr.predict(x_test)
grid_r2=r2_score(y_test,grid_pred)*100
print('Best r2 score is:',grid_r2)
# Out:
# Best r2 score is: 93.06955014951944

# %% [markdown]
# After hypertuning we got 93.06% r2 score for our model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(grid_lr,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']
